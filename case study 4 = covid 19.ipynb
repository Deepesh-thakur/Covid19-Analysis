# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corona_dataset_csv = pd.read_csv("covid19_Confirmed_dataset.csv")
corona_dataset_csv
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN         Western Sahara  24.215500 -12.885800        0
# 262            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 263            NaN                  Yemen  15.552727  48.516388        0
# 264            NaN                Comoros -11.645500  43.333300        0
# 265            NaN             Tajikistan  38.861034  71.276093        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  \
# ...

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
corona_dataset_csv.drop(['Lat','Long'],axis=1,inplace = True)

# %%
dataset_aggregate=corona_dataset_csv.groupby('Country/Region').sum()
# Out:
# C:\Users\Jojo\AppData\Local\Temp\ipykernel_15732\4287706838.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset_aggregate=corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_csv
# Out:
#     Province/State         Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  \
# 0              NaN            Afghanistan        0        0        0        0
# 1              NaN                Albania        0        0        0        0
# 2              NaN                Algeria        0        0        0        0
# 3              NaN                Andorra        0        0        0        0
# 4              NaN                 Angola        0        0        0        0
# ..             ...                    ...      ...      ...      ...      ...
# 261            NaN         Western Sahara        0        0        0        0
# 262            NaN  Sao Tome and Principe        0        0        0        0
# 263            NaN                  Yemen        0        0        0        0
# 264            NaN                Comoros        0        0        0        0
# 265            NaN             Tajikistan        0        0        0        0
#
# ...

# %%
dataset_aggregate = corona_dataset_csv.groupby('Country/Region').sum()
# Out:
# C:\Users\Jojo\AppData\Local\Temp\ipykernel_15732\3888633853.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset_aggregate = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_csv.columns
# Out:
# Index(['Province/State', 'Country/Region', '1/22/20', '1/23/20', '1/24/20',
#        '1/25/20', '1/26/20', '1/27/20', '1/28/20', '1/29/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=102)

# %%
corona_dataset_csv['1/22/20']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 261    0
# 262    0
# 263    0
# 264    0
# 265    0
# Name: 1/22/20, Length: 266, dtype: int64

# %%
# visualizing data related to a contry for example China
corona_dataset_aggregated.loc['China'][1:].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # visualizing data related to a contry for example China
# ----> 2 corona_dataset_aggregated.loc['China'][1:].plot()
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
corona_dataset_aggregated.loc['china'][1:].plot()
corona_dataset_aggregated.loc['Italy'][1:].plot()
corona_dataset_aggregated.loc['Spain'][1:].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 corona_dataset_aggregated.loc['china'][1:].plot()
#       2 corona_dataset_aggregated.loc['Italy'][1:].plot()
#       3 corona_dataset_aggregated.loc['Spain'][1:].plot()
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
corona_dataset_aggregated.loc['China'][1:4].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 corona_dataset_aggregated.loc['China'][1:4].plot()
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
corona_dataset_aggregated.iloc[36,1:],diff().plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 corona_dataset_aggregated.iloc[36,1:],diff().plot()
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
# find maximun infection rate for china
corona_dataset_aggregate.loc["China"].diff().max()
# in only 24 hrs,the difference was 6557
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # find maximun infection rate for china
# ----> 2 corona_dataset_aggregate.loc["China"].diff().max()
#
# NameError: name 'corona_dataset_aggregate' is not defined

# %%
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for c in countries:
    max_infection_rates.append(corona_dataset_aggregated.loc[c].diff().max())
    max_infection_rates
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 countries = list(corona_dataset_aggregated.index)
#       2 max_infection_rates = []
#       3 for c in countries:
#
# NameError: name 'corona_dataset_aggregated' is not defined

# %%
corona_dataset_aggregated["max_infection_rates"] = max_infection_rates
corona_dataset_aggregated.head()

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated["max_infection_rates"])
corona_data.head()

# %%
# create a new datafram with only needed column
corona_data = pd.DataFrame

# %%
happiness_report_csv = pd.read_csv("worldwide_happiness_report.csv")

# %%
happiness_report_csv.set_index("Country or region",inplace = True)
happiness_report_csv.head()

# %%
data = corona_data.join(happiness_report_csv,how = 'inner')
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 data = corona_data.join(happiness_report_csv,how = 'inner')
#       2 data.head()
#
# NameError: name 'corona_data' is not defined

# %%
sns.heatmap(data=data.corr())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 sns.heatmap(data=data.corr())
#
# NameError: name 'data' is not defined
